# %% [markdown]
# Data Science Fundamentals: R |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 14. [tidyverse](./00.ipynb) | [R Markdown](./01.ipynb) | [Basic Visualization](./02.ipynb) | [Tibbles](./03.ipynb)  | [ggplot](./04.ipynb) | [Statistical Transformations](./05.ipynb) | [Exercises](./06.ipynb)

# %% [markdown]
# ![images](images/slides17.png)

# %% [markdown]
# # Exercises

# %%
library(ggrepel)
# Out:
# Error in library(ggrepel): there is no package called ‘ggrepel’
# Traceback:
#
# 1. library(ggrepel)

# %%
library(ggplot2) 
library(ggthemes)
# Out:
# Error in library(ggthemes): there is no package called ‘ggthemes’
# Traceback:
#
# 1. library(ggthemes)

# %%
library(extrafont)
# Out:
# Error in library(extrafont): there is no package called ‘extrafont’
# Traceback:
#
# 1. library(extrafont)

# %%
library(grid)

# %%
library(cowplot)
# Out:
# Error in library(cowplot): there is no package called ‘cowplot’
# Traceback:
#
# 1. library(cowplot)

# %% [markdown]
# The [original exercises and data](http://rstudio-pubs-static.s3.amazonaws.com/284329_c7e660636fec4a42a09eed968dc47f32.html) for all the exercises is also available locally here ```./dataSets/EconomistData.csv```

# %%
library(readr)
dat <- read_csv("dataSets/EconomistData.csv")
# Out:
# Parsed with column specification:
# cols(
#   Country = col_character(),
#   HDI.Rank = col_double(),
#   HDI = col_double(),
#   CPI = col_double(),
#   Region = col_character()
# )

# %%
dat[1:5]
# Out:
#     Country                  HDI.Rank HDI   CPI Region
# 1   Afghanistan              172      0.398 1.5 Asia &\nOceania
# 2   Albania                   70      0.739 3.1 Central &\nEastern Europe
# 3   Algeria                   96      0.698 2.9 Middle East &\nnorth Africa
# 4   Angola                   148      0.486 2.0 Sub-Saharan\nAfrica
# 5   Argentina                 45      0.797 3.0 Americas
# 6   Armenia                   86      0.716 2.6 Central &\nEastern Europe
# 7   Australia                  2      0.929 8.8 Asia &\nOceania
# 8   Austria                   19      0.885 7.8 OECD
# 9   Azerbaijan                91      0.700 2.4 Central &\nEastern Europe
# 10  Bahamas                   53      0.771 7.3 Americas
# 11  Bahrain                   42      0.806 5.1 Middle East &\nnorth Africa
# 12  Bangladesh               146      0.500 2.7 Asia &\nOceania
# 13  Barbados                  47      0.793 7.8 Americas
# 14  Belarus                   65      0.756 2.4 Central &\nEastern Europe
# 15  Belgium                   18      0.886 7.5 OECD
# 16  Benin                    167      0.427 3.0 Sub-Saharan\nAfrica
# 17  Bhutan                   141      0.522 5.7 Asia &\nOceania
# 18  Bolivia                  108      0.663 2.8 Americas
# 19  Bosnia and Herzegovina    74      0.733 3.2 Central &\nEastern Europe
# 20  Botswana                 118      0.633 6.1 Sub-Saharan\nAfrica
# 21  Brazil                    84      0.718 3.8 Americas
# 22  Britain                   28      0.863 7.8 OECD
# 23  Bulgaria                  55      0.771 3.3 OECD
# 24  Burkina Faso             181      0.331 3.0 Sub-Saharan\nAfrica
# 25  Burundi                  185      0.316 1.9 Sub-Saharan\nAfrica
# 26  Cambodia                 139      0.523 2.1 Asia &\nOceania
# 27  Cameroon                 150      0.482 2.5 Sub-Saharan\nAfrica
# 28  Canada                     6      0.908 8.7 Americas
# 29  Cape Verde               133      0.568 5.5 Sub-Saharan\nAfrica
# 30  Central African Republic 179      0.343 2.2 Sub-Saharan\nAfrica
# ... ...                      ...      ...   ... ...
# 144 South Africa             123      0.619 4.1 Sub-Saharan\nAfrica
# 145 Spain                     23      0.878 6.2 OECD
# 146 Sri Lanka                 97      0.691 3.3 Asia &\nOceania
# 147 Sudan                    169      0.408 1.6 Sub-Saharan\nAfrica
# 148 Suriname                 104      0.680 3.0 Americas
# 149 Swaziland                140      0.522 3.1 Sub-Saharan\nAfrica
# 150 Sweden                    10      0.904 9.3 OECD
# 151 Switzerland               11      0.903 8.8 OECD
# 152 Syria                    119      0.632 2.6 Middle East &\nnorth Africa
# 153 Tajikistan               127      0.607 2.3 Central &\nEastern Europe
# 154 Tanzania                 152      0.466 3.0 Sub-Saharan\nAfrica
# 155 Thailand                 103      0.682 3.4 Asia &\nOceania
# 156 Timor-Leste              147      0.495 2.4 Asia &\nOceania
# 157 Togo                     162      0.435 2.4 Sub-Saharan\nAfrica
# 158 Tonga                     90      0.704 3.1 Asia &\nOceania
# 159 Trinidad and Tobago       62      0.760 3.2 Americas
# 160 Tunisia                   94      0.698 3.8 Middle East &\nnorth Africa
# 161 Turkey                    92      0.699 4.2 Central &\nEastern Europe
# 162 Turkmenistan             102      0.686 1.6 Central &\nEastern Europe
# 163 Uganda                   161      0.446 2.4 Sub-Saharan\nAfrica
# 164 Ukraine                   76      0.729 2.3 Central &\nEastern Europe
# 165 United Arab Emirates      30      0.846 6.8 Middle East &\nnorth Africa
# 166 United States              4      0.910 7.1 Americas
# 167 Uruguay                   48      0.783 7.0 Americas
# 168 Uzbekistan               115      0.641 1.6 Central &\nEastern Europe
# 169 Vanuatu                  125      0.617 3.5 Asia &\nOceania
# 170 Venezuela                 73      0.735 1.9 Americas
# 171 Yemen                    154      0.462 2.1 Middle East &\nnorth Africa
# 172 Zambia                   164      0.430 3.2 Sub-Saharan\nAfrica
# 173 Zimbabwe                 173      0.376 2.2 Sub-Saharan\nAfrica

# %%
dat$Region <- factor(dat$Region,
                     levels = c("EU W. Europe",
                                "Americas",
                                "Asia Pacific",
                                "East EU Cemt Asia",
                                "MENA",
                                "SSA"),
                     labels = c("OECD",
                                "Americas",
                                "Asia &\nOceania",
                                "Central &\nEastern Europe",
                                "Middle East &\nnorth Africa",
                                "Sub-Saharan\nAfrica"))

# %% [markdown]
# ### Exercise 1.
#
# These data consist of Human Development Index and Corruption Perception Index scores for several countries.
#
# - A. Create a scatter plot with CPI on the x axis and HDI on the y axis.
# - B. Color the points blue.
# - C. Map the color of the the points to Region.
# - D. Make the points bigger by setting size to 2
# - E. Map the size of the points to HDI.Rank

# %%
# exercise 1.a
p1 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point()
p1
# Out:
# plot without title

# %%
# exercise 1.b
p1 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point(color="blue")
p1
# Out:
# plot without title

# %%
# exercise 1.c
p1 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point(aes(color = Region))
p1
# Out:
# plot without title

# %%
# exercise 1.d
p1 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point(aes(color = Region), size=2)
p1
# Out:
# plot without title

# %%
# exercise 1.e
p1 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point(aes(color = Region, size=HDI.Rank))
p1
# Out:
# plot without title

# %% [markdown]
# ### Exercise 2.
#
# - A. Re-create a scatter plot with CPI on the x axis and HDI on the y axis (as you did in the previous exercise).
# - B. Overlay a smoothing line on top of the scatter plot using ```geom_smooth```.
# - C. Overlay a smoothing line on top of the scatter plot using ```geom_smooth```, but use a linear model for the predictions. Hint: see ```?stat_smooth```.
# - D. Overlay a smoothing line on top of the scatter plot using ```geom_line```. Hint: change the statistical transformation.
#
# - **BONUS**: Overlay a smoothing line on top of the scatter plot using the default loess method, but make it less smooth. Hint: see ```?loess```.

# %%
# exercise 2.a
p2 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point()
p2
# Out:
# plot without title

# %%
# exercise 2.b
p2 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point() + geom_smooth()
p2
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# exercise 2.c
p2 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point() + geom_smooth(method="lm")
p2
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
# exercise 2.d
p2 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point() + geom_line(stat="smooth", method="loess")
p2
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
# exercise 2.bonus
p2 <-  ggplot(dat, aes (x=CPI, y=HDI)) + geom_point() + geom_smooth(span=.4)
p2
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ### Exercise 3.
#
# - A. Create a scatter plot with CPI on the x axis and HDI on the y axis. Color the points to indicate region.
# - B. Modify the x, y, and color scales so that they have more easily-understood names (e.g., spell out “Human development Index” instead of “HDI”).
# - C. Modify the color scale to use specific values of your choosing. Hint: see ```?scale_color_manual```.

# %%
# exercise 3.a
p3 <- ggplot(dat, aes(x=CPI, y=HDI)) + geom_point(aes(color=Region))
p3
# Out:
# plot without title

# %%
# exercise 3.b
p3 <- ggplot(dat, aes(x=CPI, y=HDI)) +
geom_point(aes(color=Region)) +
scale_x_continuous(name = "Corruption Perception Index") +
scale_y_continuous(name = "Human Development Index") +
scale_color_discrete(name = "Region of the world")
p3
# Out:
# plot without title

# %%
# exercise 3.c
p3 <- ggplot(dat, aes(x = CPI, y = HDI, color=Region)) +
geom_point() +
scale_x_continuous(name = "Corruption Perception Index") +
scale_y_continuous(name = "Human Development Index") +
  scale_color_manual(name = "Region of the world",
                     values = c("#B8FF33",
                                "#FFC300",
                                "#FF5733",
                                "#C70039",
                                "#900C3F",
                                "#581845"))
p3
# Out:
# plot without title
